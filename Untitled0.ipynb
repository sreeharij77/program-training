# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeharij77/program-training/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter the number first "))
b=int(input("enter the number second "))
print ("condition using + and -")
a=a+b
b=a-b
a=a-b
print ("swap 1 a =",a)
print ("swap 1 b =",b)
print ("condition using xor")
a=a^b
b=a^b
a=a^b
print ("swap 2 a =",a)
print ("swap 2 b =",b)
print ("condition using ,")
a,b=b,a
print ("swap 3 a =",a)
print ("swap 3 b =",b)
print ("condition using temp")
temp=a
a=b
b=temp
print ("swap 4 a =",a)
print ("swap 4 b =",b)
# Out:
# enter the number first 5
# enter the number second 867
# condition using + and -
# swap 1 a = 867
# swap 1 b = 5
# condition using xor
# swap 2 a = 5
# swap 2 b = 867
# condition using ,
# swap 3 a = 867
# swap 3 b = 5
# condition using temp
# swap 4 a = 5
# swap 4 b = 867
